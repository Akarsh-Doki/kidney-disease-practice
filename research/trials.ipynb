# %%
# config box
d = {"key": "val", "key1": "val1"}

# %%
d['key1']
# Out:
# 'val1'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key": "val", "key1": "val1"})
d2.key1
type(d2)
# Out:
# box.config_box.ConfigBox

# %% [markdown]
# ## Download data from gdrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1Cj8YSn-pN4wqI-3F7J-YoMGQCuGJmJWc/view?usp=drive_link"
# all files from gdrive has a unique id

# %%
file_id=url.split("/")[-2] # use the split function to access the id
file_id
# Out:
# '1Cj8YSn-pN4wqI-3F7J-YoMGQCuGJmJWc'

# %%
prefix="https://drive.google.com/uc?/export=download&id="
gdown.download(prefix+file_id, "kidney-ct-scan-image.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1Cj8YSn-pN4wqI-3F7J-YoMGQCuGJmJWc
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1Cj8YSn-pN4wqI-3F7J-YoMGQCuGJmJWc&confirm=t&uuid=fa8be0f9-f270-48fc-8bd0-e135db833f6b
# To: /Users/Akarsh/Desktop/practiceproject/kidney-disease-practice/research/kidney-ct-scan-image.zip
# 100%|██████████| 165M/165M [00:14<00:00, 11.4MB/s]
# 'kidney-ct-scan-image.zip'
